# %% [markdown]
# # Azure Language - PII Redaction
#
# This notebook demonstrates how to use the Azure Language Analyze Text API to
# detect and redact Personally Identifiable Information (PII) from a medical report.
#
# ## Prerequisites
#
# Set the following environment variables:
# - `FOUNDRY_ENDPOINT` - Azure Language service endpoint
# - `FOUNDRY_API_KEY` - API key for authentication

# %%
import json
import os

import requests
from rich.console import Console
from rich.panel import Panel
from rich.table import Table

# %% [markdown]
# ## Load Sample Data
#
# Load the medical report containing PII from the sample data file.

# %%
with open("05-PIIRedaction-data/medical_report.txt", encoding="utf-8") as f:
    report_text = f.read()

print(f"Loaded medical report: {len(report_text)} characters")
print(f"\nFirst 500 characters:\n{report_text[:500]}...")
# Out:
# Loaded medical report: 3323 characters
#
# First 500 characters:
# MEMORIAL MEDICAL CENTER
# PATIENT MEDICAL REPORT
#
# ================================================================================
# PATIENT INFORMATION
# ================================================================================
#
# Patient Name: Joe T. Public
# Date of Birth: March 15, 1985
# Social Security Number: 482-93-7156
# Patient Account Number: MMC-2026-847291
#
# Home Address:
# 1847 Riverside Drive, Apartment 4B
# Memphis, TN 38103
#
# Contact Information:
# Primary Phone: (901) 555-7823
# Emergency Conta...

# %% [markdown]
# ## API Setup
#
# Configure the Azure Language API endpoint and authentication.

# %%
endpoint = os.environ["FOUNDRY_ENDPOINT"]
api_key = os.environ["FOUNDRY_API_KEY"]

# Construct the Analyze Text API URL
api_url = f"{endpoint}/language/:analyze-text?api-version=2024-11-01"

headers = {
    "Ocp-Apim-Subscription-Key": api_key,
    "Content-Type": "application/json",
}

print(f"API Endpoint: {endpoint}")
print("API Key: [CONFIGURED]")
# Out:
# API Endpoint: https://brad-ai-language.cognitiveservices.azure.com/
# API Key: [CONFIGURED]

# %% [markdown]
# ## Make API Call
#
# Send the medical report to the PII Entity Recognition API.

# %%
# Prepare the document for the API
documents = [{"id": "1", "language": "en", "text": report_text}]

# Build the request payload
payload = {
    "kind": "PiiEntityRecognition",
    "parameters": {"modelVersion": "latest"},
    "analysisInput": {"documents": documents},
}

# Make the API request
response = requests.post(api_url, headers=headers, json=payload, timeout=30)
response.raise_for_status()
result = response.json()

print("API call successful!")
# Out:
# API call successful!

# %% [markdown]
# ## Raw API Results
#
# Display the complete JSON response from the API.

# %%
print(json.dumps(result, indent=2))
# Out:
# {
#   "kind": "PiiEntityRecognitionResults",
#   "results": {
#     "documents": [
#       {
#         "redactedText": "MEMORIAL MEDICAL CENTER\n******* MEDICAL REPORT\n\n================================================================================\nPATIENT INFORMATION\n================================================================================\n\n******* Name: ****** Public\nDate of Birth: **************\nSocial Security Number: ***********\n******* Account Number: MMC-***********\n\nHome Address:\n**********************************\n*****************\n\nContact Information:\nPrimary Phone: **************\nEmergency Contact: *********** (****) - **************\nEmail: ****************************\n\nInsurance Information:\nProvider: ********* ********** of Tennessee\nPolicy Number: BCB-TN-9928471\nGroup Number: *********\n\n================================================================================\nCLINICAL SUMMARY\n================================================================================\n\nDate of Examination: ****************\nAttending *********: Dr. **************, **\nDepartment: Neurology and Psychiatry\n\n***** COMPLAINT:\n******* presents with persistent belief that he is deceased or does not exist, accompanied by complete absence of pain sensation.\n\nDIAGNOSIS:\n\nPrimary Diagnosis: Cotard's Syndrome (Cotard's Delusion)\nICD-10 Code: F22\n\nCotard's syndrome, also known as walking corpse syndrome, is a rare neuropsychiatric disorder characterized by nihilistic delusions. The ******* firmly believes that he is dead, does not exist, or has lost his blood and internal organs. This condition typically presents alongside severe depression and psychotic symptoms.\n\nSecondary Diagnosis: Congenital Analgesia (Congenital Insensitivity to Pain)\nICD-10 Code: G90.8\n\nThe ******* exhibits congenital analgesia, a rare inherited condition resulting in the inability to perceive physical pain. This condition has been present since birth and poses significant risks for undetected injuries. The ******* reports a history of unnoticed fractures and burns during childhood.\n\nCLINICAL OBSERVATIONS:\n\n- ******* appears oriented to time and place but demonstrates fixed delusional beliefs regarding his own existence\n- Flat affect with minimal emotional responsiveness\n- No pain response during routine examination procedures (blood draw, reflex testing)\n- Vital signs within normal limits: BP ***/**, HR ** bpm, Temp **.*\u00b0F\n- Neurological examination otherwise unremarkable\n\nTREATMENT PLAN:\n\n*. Initiate electroconvulsive therapy (ECT) evaluation for treatment-resistant Cotard's syndrome\n*. Prescribe Olanzapine 10mg daily for psychotic symptoms\n*. Prescribe Sertraline 100mg daily for underlying depression\n*. Refer to ************************** for monitoring of congenital analgesia\n*. Weekly psychiatric follow-up appointments\n*. Educate ******* and family on injury prevention strategies due to pain insensitivity\n\nFOLLOW-UP:\n******* scheduled to return on **************** for treatment response evaluation.\n\n================================================================================\nPHYSICIAN SIGNATURE\n================================================================================\n\nElectronically signed by:\n**. **************, **\nLicense Number: TN-MD-*****\nDate: ****************\n\nThis document contains Protected Health Information (PHI) and is confidential.\nUnauthorized disclosure is prohibited under ***** regulations.\n",
#         "id": "1",
#         "entities": [
#           {
#             "text": "PATIENT",
#             "category": "PersonType",
#             "offset": 24,
#             "length": 7,
#             "confidenceScore": 0.69
#           },
#           {
#             "text": "Patient",
#             "category": "PersonType",
#             "offset": 231,
#             "length": 7,
#             "confidenceScore": 0.83
#           },
#           {
#             "text": "Joe T.",
#             "category": "Person",
#             "offset": 245,
#             "length": 6,
#             "confidenceScore": 0.93
#           },
#           {
#             "text": "March 15, 1985",
#             "category": "DateTime",
#             "subcategory": "Date",
#             "offset": 274,
#             "length": 14,
#             "confidenceScore": 0.93
#           },
#           {
#             "text": "482-93-7156",
#             "category": "USSocialSecurityNumber",
#             "offset": 313,
#             "length": 11,
#             "confidenceScore": 0.85
#           },
#           {
#             "text": "Patient",
#             "category": "PersonType",
#             "offset": 325,
#             "length": 7,
#             "confidenceScore": 0.9
#           },
#           {
#             "text": "2026-847291",
#             "category": "PhoneNumber",
#             "offset": 353,
#             "length": 11,
#             "confidenceScore": 0.8
#           },
#           {
#             "text": "1847 Riverside Drive, Apartment 4B",
#             "category": "Address",
#             "offset": 380,
#             "length": 34,
#             "confidenceScore": 1.0
#           },
#           {
#             "text": "Memphis, TN 38103",
#             "category": "Address",
#             "offset": 415,
#             "length": 17,
#             "confidenceScore": 0.84
#           },
#           {
#             "text": "(901) 555-7823",
#             "category": "PhoneNumber",
#             "offset": 470,
#             "length": 14,
#             "confidenceScore": 1.0
#           },
#           {
#             "text": "Mary Public",
#             "category": "Person",
#             "offset": 504,
#             "length": 11,
#             "confidenceScore": 0.76
#           },
#           {
#             "text": "Wife",
#             "category": "PersonType",
#             "offset": 517,
#             "length": 4,
#             "confidenceScore": 0.94
#           },
#           {
#             "text": "(901) 555-7824",
#             "category": "PhoneNumber",
#             "offset": 525,
#             "length": 14,
#             "confidenceScore": 1.0
#           },
#           {
#             "text": "joe.public@emailprovider.com",
#             "category": "Email",
#             "offset": 547,
#             "length": 28,
#             "confidenceScore": 0.8
#           },
#           {
#             "text": "BlueCross",
#             "category": "Organization",
#             "offset": 610,
#             "length": 9,
#             "confidenceScore": 0.95
#           },
#           {
#             "text": "BlueShield",
#             "category": "Organization",
#             "offset": 620,
#             "length": 10,
#             "confidenceScore": 0.73
#           },
#           {
#             "text": "CORP-4421",
#             "category": "Organization",
#             "offset": 688,
#             "length": 9,
#             "confidenceScore": 0.59
#           },
#           {
#             "text": "January 20, 2026",
#             "category": "DateTime",
#             "subcategory": "Date",
#             "offset": 900,
#             "length": 16,
#             "confidenceScore": 0.96
#           },
#           {
#             "text": "Physician",
#             "category": "PersonType",
#             "offset": 927,
#             "length": 9,
#             "confidenceScore": 0.97
#           },
#           {
#             "text": "Sarah Mitchell",
#             "category": "Person",
#             "offset": 942,
#             "length": 14,
#             "confidenceScore": 0.99
#           },
#           {
#             "text": "MD",
#             "category": "PersonType",
#             "offset": 958,
#             "length": 2,
#             "confidenceScore": 0.76
#           },
#           {
#             "text": "CHIEF",
#             "category": "PersonType",
#             "offset": 999,
#             "length": 5,
#             "confidenceScore": 0.99
#           },
#           {
#             "text": "Patient",
#             "category": "PersonType",
#             "offset": 1016,
#             "length": 7,
#             "confidenceScore": 0.99
#           },
#           {
#             "text": "patient",
#             "category": "PersonType",
#             "offset": 1371,
#             "length": 7,
#             "confidenceScore": 0.99
#           },
#           {
#             "text": "patient",
#             "category": "PersonType",
#             "offset": 1659,
#             "length": 7,
#             "confidenceScore": 0.99
#           },
#           {
#             "text": "patient",
#             "category": "PersonType",
#             "offset": 1880,
#             "length": 7,
#             "confidenceScore": 0.99
#           },
#           {
#             "text": "Patient",
#             "category": "PersonType",
#             "offset": 1984,
#             "length": 7,
#             "confidenceScore": 0.96
#           },
#           {
#             "text": "118",
#             "category": "USDriversLicenseNumber",
#             "offset": 2274,
#             "length": 3,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "76",
#             "category": "USDriversLicenseNumber",
#             "offset": 2278,
#             "length": 2,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "72",
#             "category": "USDriversLicenseNumber",
#             "offset": 2285,
#             "length": 2,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "98",
#             "category": "USDriversLicenseNumber",
#             "offset": 2298,
#             "length": 2,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "4",
#             "category": "USDriversLicenseNumber",
#             "offset": 2301,
#             "length": 1,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "1",
#             "category": "USDriversLicenseNumber",
#             "offset": 2373,
#             "length": 1,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "2",
#             "category": "USDriversLicenseNumber",
#             "offset": 2470,
#             "length": 1,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "3",
#             "category": "USDriversLicenseNumber",
#             "offset": 2528,
#             "length": 1,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "4",
#             "category": "USDriversLicenseNumber",
#             "offset": 2590,
#             "length": 1,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "pain management specialist",
#             "category": "PersonType",
#             "offset": 2602,
#             "length": 26,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "5",
#             "category": "USDriversLicenseNumber",
#             "offset": 2668,
#             "length": 1,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "6",
#             "category": "USDriversLicenseNumber",
#             "offset": 2713,
#             "length": 1,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "patient",
#             "category": "PersonType",
#             "offset": 2724,
#             "length": 7,
#             "confidenceScore": 0.99
#           },
#           {
#             "text": "Patient",
#             "category": "PersonType",
#             "offset": 2813,
#             "length": 7,
#             "confidenceScore": 0.99
#           },
#           {
#             "text": "February 3, 2026",
#             "category": "DateTime",
#             "subcategory": "Date",
#             "offset": 2844,
#             "length": 16,
#             "confidenceScore": 1.0
#           },
#           {
#             "text": "Dr",
#             "category": "PersonType",
#             "offset": 3106,
#             "length": 2,
#             "confidenceScore": 0.51
#           },
#           {
#             "text": "Sarah Mitchell",
#             "category": "Person",
#             "offset": 3110,
#             "length": 14,
#             "confidenceScore": 0.99
#           },
#           {
#             "text": "MD",
#             "category": "PersonType",
#             "offset": 3126,
#             "length": 2,
#             "confidenceScore": 0.8
#           },
#           {
#             "text": "48291",
#             "category": "USDriversLicenseNumber",
#             "offset": 3151,
#             "length": 5,
#             "confidenceScore": 0.75
#           },
#           {
#             "text": "January 20, 2026",
#             "category": "DateTime",
#             "subcategory": "Date",
#             "offset": 3163,
#             "length": 16,
#             "confidenceScore": 0.96
#           },
#           {
#             "text": "HIPAA",
#             "category": "Organization",
#             "offset": 3304,
#             "length": 5,
#             "confidenceScore": 0.98
#           }
#         ],
#         "warnings": []
#       }
#     ],
#     "errors": [],
#     "modelVersion": "2025-11-01"
#   }
# }

# %% [markdown]
# ## Human-Friendly Results
#
# Present the PII detection and redaction results in a readable format.

# %%
console = Console()

# Extract document result
doc_result = result["results"]["documents"][0]
entities = doc_result["entities"]
redacted_text = doc_result.get("redactedText", "")

# Create PII entities table
table = Table(title="Detected PII Entities")
table.add_column("Entity Text", style="red")
table.add_column("Category", style="cyan")
table.add_column("Subcategory", style="dim")
table.add_column("Confidence", justify="center")

for entity in entities:
    subcategory = entity.get("subcategory", "-")
    confidence = f"{entity['confidenceScore']:.0%}"
    table.add_row(entity["text"], entity["category"], subcategory, confidence)

console.print(table)

# Group by category for summary
categories: dict[str, list[str]] = {}
for entity in entities:
    cat = entity["category"]
    if cat not in categories:
        categories[cat] = []
    categories[cat].append(entity["text"])

# Category summary
console.print("\n")
summary_table = Table(title="PII Summary by Category")
summary_table.add_column("Category", style="bold cyan")
summary_table.add_column("Count", justify="center", style="red")
summary_table.add_column("Examples", style="dim")

for cat, items in sorted(categories.items()):
    examples = ", ".join(items[:3])
    if len(items) > 3:
        examples += f" (+{len(items) - 3} more)"
    summary_table.add_row(cat, str(len(items)), examples)

console.print(summary_table)
# Out:
#                                   Detected PII Entities
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Entity Text                        ┃ Category               ┃ Subcategory ┃ Confidence ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ PATIENT                            │ PersonType             │ -           │    69%     │
# │ Patient                            │ PersonType             │ -           │    83%     │
# │ Joe T.                             │ Person                 │ -           │    93%     │
# │ March 15, 1985                     │ DateTime               │ Date        │    93%     │
# │ 482-93-7156                        │ USSocialSecurityNumber │ -           │    85%     │
# │ Patient                            │ PersonType             │ -           │    90%     │
# │ 2026-847291                        │ PhoneNumber            │ -           │    80%     │
# │ 1847 Riverside Drive, Apartment 4B │ Address                │ -           │    100%    │
# │ Memphis, TN 38103                  │ Address                │ -           │    84%     │
# │ (901) 555-7823                     │ PhoneNumber            │ -           │    100%    │
# │ Mary Public                        │ Person                 │ -           │    76%     │
# │ Wife                               │ PersonType             │ -           │    94%     │
# │ (901) 555-7824                     │ PhoneNumber            │ -           │    100%    │
# │ joe.public@emailprovider.com       │ Email                  │ -           │    80%     │
# │ BlueCross                          │ Organization           │ -           │    95%     │
# │ BlueShield                         │ Organization           │ -           │    73%     │
# │ CORP-4421                          │ Organization           │ -           │    59%     │
# │ January 20, 2026                   │ DateTime               │ Date        │    96%     │
# │ Physician                          │ PersonType             │ -           │    97%     │
# │ Sarah Mitchell                     │ Person                 │ -           │    99%     │
# │ MD                                 │ PersonType             │ -           │    76%     │
# │ CHIEF                              │ PersonType             │ -           │    99%     │
# │ Patient                            │ PersonType             │ -           │    99%     │
# │ patient                            │ PersonType             │ -           │    99%     │
# │ patient                            │ PersonType             │ -           │    99%     │
# │ patient                            │ PersonType             │ -           │    99%     │
# │ Patient                            │ PersonType             │ -           │    96%     │
# │ 118                                │ USDriversLicenseNumber │ -           │    75%     │
# │ 76                                 │ USDriversLicenseNumber │ -           │    75%     │
# │ 72                                 │ USDriversLicenseNumber │ -           │    75%     │
# │ 98                                 │ USDriversLicenseNumber │ -           │    75%     │
# │ 4                                  │ USDriversLicenseNumber │ -           │    75%     │
# │ 1                                  │ USDriversLicenseNumber │ -           │    75%     │
# │ 2                                  │ USDriversLicenseNumber │ -           │    75%     │
# │ 3                                  │ USDriversLicenseNumber │ -           │    75%     │
# │ 4                                  │ USDriversLicenseNumber │ -           │    75%     │
# │ pain management specialist         │ PersonType             │ -           │    75%     │
# │ 5                                  │ USDriversLicenseNumber │ -           │    75%     │
# │ 6                                  │ USDriversLicenseNumber │ -           │    75%     │
# │ patient                            │ PersonType             │ -           │    99%     │
# │ Patient                            │ PersonType             │ -           │    99%     │
# │ February 3, 2026                   │ DateTime               │ Date        │    100%    │
# │ Dr                                 │ PersonType             │ -           │    51%     │
# │ Sarah Mitchell                     │ Person                 │ -           │    99%     │
# │ MD                                 │ PersonType             │ -           │    80%     │
# │ 48291                              │ USDriversLicenseNumber │ -           │    75%     │
# │ January 20, 2026                   │ DateTime               │ Date        │    96%     │
# │ HIPAA                              │ Organization           │ -           │    98%     │
# └────────────────────────────────────┴────────────────────────┴─────────────┴────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                      PII Summary by Category
# ┏━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Category               ┃ Count ┃ Examples                                                     ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Address                │   2   │ 1847 Riverside Drive, Apartment 4B, Memphis, TN 38103        │
# │ DateTime               │   4   │ March 15, 1985, January 20, 2026, February 3, 2026 (+1 more) │
# │ Email                  │   1   │ joe.public@emailprovider.com                                 │
# │ Organization           │   4   │ BlueCross, BlueShield, CORP-4421 (+1 more)                   │
# │ Person                 │   4   │ Joe T., Mary Public, Sarah Mitchell (+1 more)                │
# │ PersonType             │  17   │ PATIENT, Patient, Patient (+14 more)                         │
# │ PhoneNumber            │   3   │ 2026-847291, (901) 555-7823, (901) 555-7824                  │
# │ USDriversLicenseNumber │  12   │ 118, 76, 72 (+9 more)                                        │
# │ USSocialSecurityNumber │   1   │ 482-93-7156                                                  │
# └────────────────────────┴───────┴──────────────────────────────────────────────────────────────┘

# %% [markdown]
# ## Redacted Document
#
# Display the document with PII entities redacted.

# %%
# Display redacted text if available from API
if redacted_text:
    console.print(Panel(redacted_text, title="Redacted Medical Report (API Output)"))
else:
    # Manually redact using entity offsets
    # Sort entities by offset in reverse order to preserve positions
    sorted_entities = sorted(entities, key=lambda e: e["offset"], reverse=True)

    redacted = report_text
    for entity in sorted_entities:
        start = entity["offset"]
        end = start + entity["length"]
        replacement = f"[{entity['category']}]"
        redacted = redacted[:start] + replacement + redacted[end:]

    console.print(Panel(redacted, title="Redacted Medical Report (Manual Redaction)"))

# Warning panel
warning = """
[bold yellow]⚠️ PII Detection Summary:[/bold yellow]

This document contained [bold red]{count}[/bold red] pieces of personally identifiable information:

• Social Security Numbers
• Phone Numbers
• Addresses
• Names
• Account Numbers
• Email Addresses

[dim]PII redaction is essential for HIPAA compliance and protecting patient privacy.[/dim]
""".format(count=len(entities))

console.print(Panel(warning, title="Privacy Alert", border_style="yellow"))
# Out:
# ╭───────────────────────────────────── Redacted Medical Report (API Output) ──────────────────────────────────────╮
# │ MEMORIAL MEDICAL CENTER                                                                                         │
# │ ******* MEDICAL REPORT                                                                                          │
# │                                                                                                                 │
# │ ================================================================================                                │
# │ PATIENT INFORMATION                                                                                             │
# │ ================================================================================                                │
# │                                                                                                                 │
# │ ******* Name: ****** Public                                                                                     │
# │ Date of Birth: **************                                                                                   │
# │ Social Security Number: ***********                                                                             │
# │ ******* Account Number: MMC-***********                                                                         │
# │                                                                                                                 │
# │ Home Address:                                                                                                   │
# │ **********************************                                                                              │
# │ *****************                                                                                               │
# │                                                                                                                 │
# │ Contact Information:                                                                                            │
# │ Primary Phone: **************                                                                                   │
# │ Emergency Contact: *********** (****) - **************                                                          │
# │ Email: ****************************                                                                             │
# │                                                                                                                 │
# │ Insurance Information:                                                                                          │
# │ Provider: ********* ********** of Tennessee                                                                     │
# │ Policy Number: BCB-TN-9928471                                                                                   │
# │ Group Number: *********                                                                                         │
# │                                                                                                                 │
# │ ================================================================================                                │
# │ CLINICAL SUMMARY                                                                                                │
# │ ================================================================================                                │
# │                                                                                                                 │
# │ Date of Examination: ****************                                                                           │
# │ Attending *********: Dr. **************, **                                                                     │
# │ Department: Neurology and Psychiatry                                                                            │
# │                                                                                                                 │
# │ ***** COMPLAINT:                                                                                                │
# │ ******* presents with persistent belief that he is deceased or does not exist, accompanied by complete absence  │
# │ of pain sensation.                                                                                              │
# │                                                                                                                 │
# │ DIAGNOSIS:                                                                                                      │
# │                                                                                                                 │
# │ Primary Diagnosis: Cotard's Syndrome (Cotard's Delusion)                                                        │
# │ ICD-10 Code: F22                                                                                                │
# │                                                                                                                 │
# │ Cotard's syndrome, also known as walking corpse syndrome, is a rare neuropsychiatric disorder characterized by  │
# │ nihilistic delusions. The ******* firmly believes that he is dead, does not exist, or has lost his blood and    │
# │ internal organs. This condition typically presents alongside severe depression and psychotic symptoms.          │
# │                                                                                                                 │
# │ Secondary Diagnosis: Congenital Analgesia (Congenital Insensitivity to Pain)                                    │
# │ ICD-10 Code: G90.8                                                                                              │
# │                                                                                                                 │
# │ The ******* exhibits congenital analgesia, a rare inherited condition resulting in the inability to perceive    │
# │ physical pain. This condition has been present since birth and poses significant risks for undetected injuries. │
# │ The ******* reports a history of unnoticed fractures and burns during childhood.                                │
# │                                                                                                                 │
# │ CLINICAL OBSERVATIONS:                                                                                          │
# │                                                                                                                 │
# │ - ******* appears oriented to time and place but demonstrates fixed delusional beliefs regarding his own        │
# │ existence                                                                                                       │
# │ - Flat affect with minimal emotional responsiveness                                                             │
# │ - No pain response during routine examination procedures (blood draw, reflex testing)                           │
# │ - Vital signs within normal limits: BP ***/**, HR ** bpm, Temp **.*°F                                           │
# │ - Neurological examination otherwise unremarkable                                                               │
# │                                                                                                                 │
# │ TREATMENT PLAN:                                                                                                 │
# │                                                                                                                 │
# │ *. Initiate electroconvulsive therapy (ECT) evaluation for treatment-resistant Cotard's syndrome                │
# │ *. Prescribe Olanzapine 10mg daily for psychotic symptoms                                                       │
# │ *. Prescribe Sertraline 100mg daily for underlying depression                                                   │
# │ *. Refer to ************************** for monitoring of congenital analgesia                                   │
# │ *. Weekly psychiatric follow-up appointments                                                                    │
# │ *. Educate ******* and family on injury prevention strategies due to pain insensitivity                         │
# │                                                                                                                 │
# │ FOLLOW-UP:                                                                                                      │
# │ ******* scheduled to return on **************** for treatment response evaluation.                              │
# │                                                                                                                 │
# │ ================================================================================                                │
# │ PHYSICIAN SIGNATURE                                                                                             │
# │ ================================================================================                                │
# │                                                                                                                 │
# │ Electronically signed by:                                                                                       │
# │ **. **************, **                                                                                          │
# │ License Number: TN-MD-*****                                                                                     │
# │ Date: ****************                                                                                          │
# │                                                                                                                 │
# │ This document contains Protected Health Information (PHI) and is confidential.                                  │
# │ Unauthorized disclosure is prohibited under ***** regulations.                                                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭───────────────────────────────────────────────── Privacy Alert ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ ⚠️ PII Detection Summary:                                                                                       │
# │                                                                                                                 │
# │ This document contained 48 pieces of personally identifiable information:                                       │
# │                                                                                                                 │
# │ • Social Security Numbers                                                                                       │
# │ • Phone Numbers                                                                                                 │
# │ • Addresses                                                                                                     │
# │ • Names                                                                                                         │
# │ • Account Numbers                                                                                               │
# │ • Email Addresses                                                                                               │
# │                                                                                                                 │
# │ PII redaction is essential for HIPAA compliance and protecting patient privacy.                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
