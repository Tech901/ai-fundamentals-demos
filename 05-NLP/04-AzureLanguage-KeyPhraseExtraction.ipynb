# %% [markdown]
# # Azure Language - Key Phrase Extraction
#
# This notebook demonstrates how to use the Azure Language Analyze Text API to
# extract key phrases from an essay about exercise and nutrition.
#
# ## Prerequisites
#
# Set the following environment variables:
# - `FOUNDRY_ENDPOINT` - Azure Language service endpoint
# - `FOUNDRY_API_KEY` - API key for authentication

# %%
import json
import os

import requests
from rich.columns import Columns
from rich.console import Console
from rich.panel import Panel
from rich.table import Table

# %% [markdown]
# ## Load Sample Data
#
# Load the essay on exercise and nutrition from the sample data file.

# %%
with open(
    "04-KeyPhraseExtraction-data/exercise_nutrition_essay.txt", encoding="utf-8"
) as f:
    essay_text = f.read()

# Count words
word_count = len(essay_text.split())
print(f"Loaded essay: {len(essay_text)} characters, {word_count} words")
print(f"\nFirst 300 characters:\n{essay_text[:300]}...")
# Out:
# Loaded essay: 3252 characters, 429 words
#
# First 300 characters:
# The Transformative Power of Exercise and Nutrition: Building a Foundation for Lifelong Health
#
# In today's fast-paced world, maintaining optimal health through regular exercise and proper nutrition has become more important than ever. These two pillars of wellness work synergistically to enhance phys...

# %% [markdown]
# ## API Setup
#
# Configure the Azure Language API endpoint and authentication.

# %%
endpoint = os.environ["FOUNDRY_ENDPOINT"]
api_key = os.environ["FOUNDRY_API_KEY"]

# Construct the Analyze Text API URL
api_url = f"{endpoint}/language/:analyze-text?api-version=2024-11-01"

headers = {
    "Ocp-Apim-Subscription-Key": api_key,
    "Content-Type": "application/json",
}

print(f"API Endpoint: {endpoint}")
print("API Key: [CONFIGURED]")
# Out:
# API Endpoint: https://brad-ai-language.cognitiveservices.azure.com/
# API Key: [CONFIGURED]

# %% [markdown]
# ## Make API Call
#
# Send the essay to the Key Phrase Extraction API.

# %%
# Prepare the document for the API
documents = [{"id": "1", "language": "en", "text": essay_text}]

# Build the request payload
payload = {
    "kind": "KeyPhraseExtraction",
    "parameters": {"modelVersion": "latest"},
    "analysisInput": {"documents": documents},
}

# Make the API request
response = requests.post(api_url, headers=headers, json=payload, timeout=30)
response.raise_for_status()
result = response.json()

print("API call successful!")
# Out:
# API call successful!

# %% [markdown]
# ## Raw API Results
#
# Display the complete JSON response from the API.

# %%
print(json.dumps(result, indent=2))
# Out:
# {
#   "kind": "KeyPhraseExtractionResults",
#   "results": {
#     "documents": [
#       {
#         "id": "1",
#         "keyPhrases": [
#           "powerful positive feedback loop",
#           "natural mood elevators",
#           "simple mood improvement",
#           "Consulting healthcare professionals",
#           "small, achievable goals",
#           "certified fitness experts",
#           "sustainable long-term health",
#           "lean muscle mass",
#           "Regular physical activity",
#           "healthy body weight",
#           "mental health benefits",
#           "fitness goals",
#           "remarkable benefits",
#           "lean proteins",
#           "physical performance",
#           "mental clarity",
#           "physical recovery",
#           "mental restoration",
#           "physical achievements",
#           "healthy fats",
#           "healthy habits",
#           "heart muscle",
#           "muscle recovery",
#           "muscle function",
#           "Lifelong Health",
#           "optimal health",
#           "bone health",
#           "health conditions",
#           "Transformative Power",
#           "two pillars",
#           "wellness work",
#           "overall quality",
#           "human body",
#           "blood circulation",
#           "heart disease",
#           "Resistance training",
#           "bone density",
#           "cognitive function",
#           "memory retention",
#           "neurodegenerative diseases",
#           "sleep quality",
#           "balanced diet",
#           "energy production",
#           "tissue repair",
#           "immune function",
#           "Protein intake",
#           "complex carbohydrates",
#           "sustained energy",
#           "demanding workouts",
#           "important roles",
#           "vitamin D",
#           "oxidative damage",
#           "oxygen transport",
#           "bone strength",
#           "body temperature",
#           "waste products",
#           "active individuals",
#           "fluid intake",
#           "nutrient absorption",
#           "personalized guidance",
#           "individual circumstances",
#           "impactful investments",
#           "lifestyle choices",
#           "daily performance",
#           "regular exercise",
#           "proper nutrition",
#           "essential nutrients",
#           "energy metabolism",
#           "vitamins C",
#           "balanced nutrition",
#           "vibrant life",
#           "Cardiovascular exercise",
#           "disease risk",
#           "The",
#           "Foundation",
#           "today",
#           "world",
#           "running",
#           "swimming",
#           "cycling",
#           "release",
#           "endorphins",
#           "stress",
#           "anxiety",
#           "depression",
#           "Studies",
#           "Alzheimer",
#           "whole",
#           "grains",
#           "fruits",
#           "vegetables",
#           "growth",
#           "Micronutrients",
#           "B-complex",
#           "antioxidants",
#           "cells",
#           "Minerals",
#           "iron",
#           "calcium",
#           "magnesium",
#           "Hydration",
#           "aspect",
#           "Water",
#           "joints",
#           "Athletes",
#           "losses",
#           "perspiration",
#           "combination",
#           "efficiency",
#           "utilization",
#           "synergy",
#           "progress",
#           "consistency",
#           "patience",
#           "intensity",
#           "injury",
#           "burnout",
#           "conclusion",
#           "future"
#         ],
#         "warnings": []
#       }
#     ],
#     "errors": [],
#     "modelVersion": "2022-10-01"
#   }
# }

# %% [markdown]
# ## Human-Friendly Results
#
# Present the extracted key phrases in a readable format.

# %%
console = Console()

# Extract key phrases from the result
key_phrases = result["results"]["documents"][0]["keyPhrases"]

console.print(
    Panel(
        f"[bold green]{len(key_phrases)}[/bold green] key phrases extracted",
        title="Key Phrase Extraction Results",
    )
)

# Create a table with key phrases
table = Table(title="Extracted Key Phrases")
table.add_column("#", style="cyan", justify="right", width=4)
table.add_column("Key Phrase", style="green")
table.add_column("Word Count", justify="center", style="dim")

for i, phrase in enumerate(key_phrases, 1):
    word_ct = len(phrase.split())
    table.add_row(str(i), phrase, str(word_ct))

console.print(table)

# Categorize key phrases by theme
exercise_terms = [
    p
    for p in key_phrases
    if any(
        w in p.lower()
        for w in [
            "exercise",
            "physical",
            "cardio",
            "training",
            "workout",
            "muscle",
            "fitness",
        ]
    )
]
nutrition_terms = [
    p
    for p in key_phrases
    if any(
        w in p.lower()
        for w in [
            "nutrition",
            "diet",
            "food",
            "vitamin",
            "protein",
            "carb",
            "mineral",
            "nutrient",
        ]
    )
]
health_terms = [
    p
    for p in key_phrases
    if any(
        w in p.lower()
        for w in [
            "health",
            "mental",
            "cognitive",
            "disease",
            "wellness",
            "sleep",
            "body",
        ]
    )
]

# Display categorized phrases
categories = [
    ("Exercise & Fitness", exercise_terms, "cyan"),
    ("Nutrition & Diet", nutrition_terms, "green"),
    ("Health & Wellness", health_terms, "magenta"),
]

console.print("\n")
panels = []
for title, terms, color in categories:
    if terms:
        content = "\n".join(f"• {t}" for t in terms[:8])
        if len(terms) > 8:
            content += f"\n... and {len(terms) - 8} more"
        panels.append(
            Panel(content, title=f"[{color}]{title}[/{color}]", border_style=color)
        )

if panels:
    console.print(Columns(panels, equal=True))

# Summary
summary = f"""
[bold]Document Analysis Summary:[/bold]

• Total Key Phrases: [cyan]{len(key_phrases)}[/cyan]
• Document Length: [cyan]{word_count}[/cyan] words
• Key Phrase Density: [cyan]{len(key_phrases) / word_count * 100:.1f}%[/cyan]

[dim]Key phrases represent the main topics and concepts discussed in the text.[/dim]
"""

console.print(Panel(summary, title="Summary"))
# Out:
# ╭───────────────────────────────────────── Key Phrase Extraction Results ─────────────────────────────────────────╮
# │ 119 key phrases extracted                                                                                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
#                    Extracted Key Phrases
# ┏━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃    # ┃ Key Phrase                          ┃ Word Count ┃
# ┡━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │    1 │ powerful positive feedback loop     │     4      │
# │    2 │ natural mood elevators              │     3      │
# │    3 │ simple mood improvement             │     3      │
# │    4 │ Consulting healthcare professionals │     3      │
# │    5 │ small, achievable goals             │     3      │
# │    6 │ certified fitness experts           │     3      │
# │    7 │ sustainable long-term health        │     3      │
# │    8 │ lean muscle mass                    │     3      │
# │    9 │ Regular physical activity           │     3      │
# │   10 │ healthy body weight                 │     3      │
# │   11 │ mental health benefits              │     3      │
# │   12 │ fitness goals                       │     2      │
# │   13 │ remarkable benefits                 │     2      │
# │   14 │ lean proteins                       │     2      │
# │   15 │ physical performance                │     2      │
# │   16 │ mental clarity                      │     2      │
# │   17 │ physical recovery                   │     2      │
# │   18 │ mental restoration                  │     2      │
# │   19 │ physical achievements               │     2      │
# │   20 │ healthy fats                        │     2      │
# │   21 │ healthy habits                      │     2      │
# │   22 │ heart muscle                        │     2      │
# │   23 │ muscle recovery                     │     2      │
# │   24 │ muscle function                     │     2      │
# │   25 │ Lifelong Health                     │     2      │
# │   26 │ optimal health                      │     2      │
# │   27 │ bone health                         │     2      │
# │   28 │ health conditions                   │     2      │
# │   29 │ Transformative Power                │     2      │
# │   30 │ two pillars                         │     2      │
# │   31 │ wellness work                       │     2      │
# │   32 │ overall quality                     │     2      │
# │   33 │ human body                          │     2      │
# │   34 │ blood circulation                   │     2      │
# │   35 │ heart disease                       │     2      │
# │   36 │ Resistance training                 │     2      │
# │   37 │ bone density                        │     2      │
# │   38 │ cognitive function                  │     2      │
# │   39 │ memory retention                    │     2      │
# │   40 │ neurodegenerative diseases          │     2      │
# │   41 │ sleep quality                       │     2      │
# │   42 │ balanced diet                       │     2      │
# │   43 │ energy production                   │     2      │
# │   44 │ tissue repair                       │     2      │
# │   45 │ immune function                     │     2      │
# │   46 │ Protein intake                      │     2      │
# │   47 │ complex carbohydrates               │     2      │
# │   48 │ sustained energy                    │     2      │
# │   49 │ demanding workouts                  │     2      │
# │   50 │ important roles                     │     2      │
# │   51 │ vitamin D                           │     2      │
# │   52 │ oxidative damage                    │     2      │
# │   53 │ oxygen transport                    │     2      │
# │   54 │ bone strength                       │     2      │
# │   55 │ body temperature                    │     2      │
# │   56 │ waste products                      │     2      │
# │   57 │ active individuals                  │     2      │
# │   58 │ fluid intake                        │     2      │
# │   59 │ nutrient absorption                 │     2      │
# │   60 │ personalized guidance               │     2      │
# │   61 │ individual circumstances            │     2      │
# │   62 │ impactful investments               │     2      │
# │   63 │ lifestyle choices                   │     2      │
# │   64 │ daily performance                   │     2      │
# │   65 │ regular exercise                    │     2      │
# │   66 │ proper nutrition                    │     2      │
# │   67 │ essential nutrients                 │     2      │
# │   68 │ energy metabolism                   │     2      │
# │   69 │ vitamins C                          │     2      │
# │   70 │ balanced nutrition                  │     2      │
# │   71 │ vibrant life                        │     2      │
# │   72 │ Cardiovascular exercise             │     2      │
# │   73 │ disease risk                        │     2      │
# │   74 │ The                                 │     1      │
# │   75 │ Foundation                          │     1      │
# │   76 │ today                               │     1      │
# │   77 │ world                               │     1      │
# │   78 │ running                             │     1      │
# │   79 │ swimming                            │     1      │
# │   80 │ cycling                             │     1      │
# │   81 │ release                             │     1      │
# │   82 │ endorphins                          │     1      │
# │   83 │ stress                              │     1      │
# │   84 │ anxiety                             │     1      │
# │   85 │ depression                          │     1      │
# │   86 │ Studies                             │     1      │
# │   87 │ Alzheimer                           │     1      │
# │   88 │ whole                               │     1      │
# │   89 │ grains                              │     1      │
# │   90 │ fruits                              │     1      │
# │   91 │ vegetables                          │     1      │
# │   92 │ growth                              │     1      │
# │   93 │ Micronutrients                      │     1      │
# │   94 │ B-complex                           │     1      │
# │   95 │ antioxidants                        │     1      │
# │   96 │ cells                               │     1      │
# │   97 │ Minerals                            │     1      │
# │   98 │ iron                                │     1      │
# │   99 │ calcium                             │     1      │
# │  100 │ magnesium                           │     1      │
# │  101 │ Hydration                           │     1      │
# │  102 │ aspect                              │     1      │
# │  103 │ Water                               │     1      │
# │  104 │ joints                              │     1      │
# │  105 │ Athletes                            │     1      │
# │  106 │ losses                              │     1      │
# │  107 │ perspiration                        │     1      │
# │  108 │ combination                         │     1      │
# │  109 │ efficiency                          │     1      │
# │  110 │ utilization                         │     1      │
# │  111 │ synergy                             │     1      │
# │  112 │ progress                            │     1      │
# │  113 │ consistency                         │     1      │
# │  114 │ patience                            │     1      │
# │  115 │ intensity                           │     1      │
# │  116 │ injury                              │     1      │
# │  117 │ burnout                             │     1      │
# │  118 │ conclusion                          │     1      │
# │  119 │ future                              │     1      │
# └──────┴─────────────────────────────────────┴────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭───────── Exercise & Fitness ──────────╮ ╭─── Nutrition & Diet ────╮
# │ • certified fitness experts           │ │ • lean proteins         │
# │ • lean muscle mass                    │ │ • balanced diet         │
# │ • Regular physical activity           │ │ • Protein intake        │
# │ • fitness goals                       │ │ • complex carbohydrates │
# │ • physical performance                │ │ • vitamin D             │
# │ • physical recovery                   │ │ • nutrient absorption   │
# │ • physical achievements               │ │ • proper nutrition      │
# │ • heart muscle                        │ │ • essential nutrients   │
# │ ... and 6 more                        │ │ ... and 4 more          │
# ╰───────────────────────────────────────╯ ╰─────────────────────────╯
# ╭────────── Health & Wellness ──────────╮
# │ • Consulting healthcare professionals │
# │ • sustainable long-term health        │
# │ • healthy body weight                 │
# │ • mental health benefits              │
# │ • mental clarity                      │
# │ • mental restoration                  │
# │ • healthy fats                        │
# │ • healthy habits                      │
# │ ... and 12 more                       │
# ╰───────────────────────────────────────╯
# ╭──────────────────────────────────────────────────── Summary ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Document Analysis Summary:                                                                                      │
# │                                                                                                                 │
# │ • Total Key Phrases: 119                                                                                        │
# │ • Document Length: 429 words                                                                                    │
# │ • Key Phrase Density: 27.7%                                                                                     │
# │                                                                                                                 │
# │ Key phrases represent the main topics and concepts discussed in the text.                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
