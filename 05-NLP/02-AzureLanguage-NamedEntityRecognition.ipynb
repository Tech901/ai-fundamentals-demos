# %% [markdown]
# # Azure Language - Named Entity Recognition
#
# This notebook demonstrates how to use the Azure Language Analyze Text API to perform
# Named Entity Recognition (NER) on a business contract between Aperture Laboratories
# and Umbrella Corporation.
#
# ## Prerequisites
#
# Set the following environment variables:
# - `FOUNDRY_ENDPOINT` - Azure Language service endpoint
# - `FOUNDRY_API_KEY` - API key for authentication

# %%
import json
import os

import requests
from rich.console import Console
from rich.panel import Panel
from rich.table import Table

# %% [markdown]
# ## Load Sample Data
#
# Load the business contract from the sample data file.

# %%
with open(
    "02-NamedEntityRecognition-data/business_contract.txt", encoding="utf-8"
) as f:
    contract_text = f.read()

print(f"Loaded contract: {len(contract_text)} characters")
print(f"\nFirst 500 characters:\n{contract_text[:500]}...")
# Out:
# Loaded contract: 3358 characters
#
# First 500 characters:
# MASTER SERVICES AGREEMENT
#
# This Master Services Agreement ("Agreement") is entered into as of January 15, 2026, by and between:
#
# APERTURE LABORATORIES, INC., a Delaware corporation with its principal place of business at 1500 Innovation Drive, Cleveland, Ohio 44113 ("Provider"), and
#
# UMBRELLA CORPORATION, a multinational conglomerate incorporated in the State of New York with headquarters at 2800 Corporate Plaza, Suite 500, Raccoon City, New York 10001 ("Client").
#
# WHEREAS, Provider specializes ...

# %% [markdown]
# ## API Setup
#
# Configure the Azure Language API endpoint and authentication.

# %%
endpoint = os.environ["FOUNDRY_ENDPOINT"]
api_key = os.environ["FOUNDRY_API_KEY"]

# Construct the Analyze Text API URL
api_url = f"{endpoint}/language/:analyze-text?api-version=2024-11-01"

headers = {
    "Ocp-Apim-Subscription-Key": api_key,
    "Content-Type": "application/json",
}

print(f"API Endpoint: {endpoint}")
print("API Key: [CONFIGURED]")
# Out:
# API Endpoint: https://brad-ai-language.cognitiveservices.azure.com/
# API Key: [CONFIGURED]

# %% [markdown]
# ## Make API Call
#
# Send the contract text to the Named Entity Recognition API.

# %%
# Prepare the document for the API
documents = [{"id": "1", "language": "en", "text": contract_text}]

# Build the request payload
payload = {
    "kind": "EntityRecognition",
    "parameters": {"modelVersion": "latest"},
    "analysisInput": {"documents": documents},
}

# Make the API request
response = requests.post(api_url, headers=headers, json=payload, timeout=30)
response.raise_for_status()
result = response.json()

print("API call successful!")
# Out:
# API call successful!

# %% [markdown]
# ## Raw API Results
#
# Display the complete JSON response from the API.

# %%
print(json.dumps(result, indent=2))
# Out:
# {
#   "kind": "EntityRecognitionResults",
#   "results": {
#     "documents": [
#       {
#         "id": "1",
#         "entities": [
#           {
#             "text": "January 15, 2026",
#             "category": "DateTime",
#             "subcategory": "Date",
#             "type": "Date",
#             "offset": 94,
#             "length": 16,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Date",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "DateTime",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "DateMetadata",
#               "dateValues": [
#                 {
#                   "timex": "2026-01-15",
#                   "value": "2026-01-15"
#                 }
#               ]
#             }
#           },
#           {
#             "text": "APERTURE LABORATORIES, INC.",
#             "category": "Organization",
#             "type": "Organization",
#             "offset": 129,
#             "length": 27,
#             "confidenceScore": 0.86,
#             "tags": [
#               {
#                 "name": "Organization",
#                 "confidenceScore": 0.86
#               }
#             ]
#           },
#           {
#             "text": "Delaware",
#             "category": "Location",
#             "subcategory": "State",
#             "type": "State",
#             "offset": 160,
#             "length": 8,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "State",
#                 "confidenceScore": 0.99
#               },
#               {
#                 "name": "GPE",
#                 "confidenceScore": 0.99
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "1500 Innovation Drive, Cleveland, Ohio 44113",
#             "category": "Address",
#             "type": "Address",
#             "offset": 221,
#             "length": 44,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "Address",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "UMBRELLA CORPORATION",
#             "category": "Organization",
#             "type": "Organization",
#             "offset": 285,
#             "length": 20,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "Organization",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "State of New York",
#             "category": "Location",
#             "subcategory": "GPE",
#             "type": "GPE",
#             "offset": 356,
#             "length": 17,
#             "confidenceScore": 0.76,
#             "tags": [
#               {
#                 "name": "GPE",
#                 "confidenceScore": 0.76
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.76
#               }
#             ]
#           },
#           {
#             "text": "headquarters",
#             "category": "Location",
#             "subcategory": "Structural",
#             "type": "Structural",
#             "offset": 379,
#             "length": 12,
#             "confidenceScore": 0.54,
#             "tags": [
#               {
#                 "name": "Structural",
#                 "confidenceScore": 0.54
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.54
#               }
#             ]
#           },
#           {
#             "text": "2800 Corporate Plaza, Suite 500, Raccoon City, New York 10001",
#             "category": "Address",
#             "type": "Address",
#             "offset": 395,
#             "length": 61,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "Address",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "machine learning",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 512,
#             "length": 16,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "artificial intelligence research",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 540,
#             "length": 32,
#             "confidenceScore": 0.76,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.76
#               }
#             ]
#           },
#           {
#             "text": "data analytics services",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 578,
#             "length": 23,
#             "confidenceScore": 0.84,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.84
#               }
#             ]
#           },
#           {
#             "text": "Client",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 617,
#             "length": 6,
#             "confidenceScore": 0.92,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.92
#               }
#             ]
#           },
#           {
#             "text": "machine learning",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 662,
#             "length": 16,
#             "confidenceScore": 0.97,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.97
#               }
#             ]
#           },
#           {
#             "text": "model development",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 700,
#             "length": 17,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "AI infrastructure",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 723,
#             "length": 17,
#             "confidenceScore": 0.83,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.83
#               }
#             ]
#           },
#           {
#             "text": "NOW",
#             "category": "DateTime",
#             "type": "DateAndTime",
#             "offset": 751,
#             "length": 3,
#             "confidenceScore": 0.7,
#             "tags": [
#               {
#                 "name": "DateAndTime",
#                 "confidenceScore": 0.7
#               },
#               {
#                 "name": "DateTime",
#                 "confidenceScore": 0.7
#               }
#             ]
#           },
#           {
#             "text": "1",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 877,
#             "length": 1,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 1.0
#             }
#           },
#           {
#             "text": "1.1",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 899,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 1.1
#             }
#           },
#           {
#             "text": "Provider",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 903,
#             "length": 8,
#             "confidenceScore": 0.91,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.91
#               }
#             ]
#           },
#           {
#             "text": "Client",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 956,
#             "length": 6,
#             "confidenceScore": 0.97,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.97
#               }
#             ]
#           },
#           {
#             "text": "Development",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 971,
#             "length": 11,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "pharmaceutical research",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 1036,
#             "length": 23,
#             "confidenceScore": 0.84,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.84
#               }
#             ]
#           },
#           {
#             "text": "optimization",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 1060,
#             "length": 12,
#             "confidenceScore": 0.7,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.7
#               }
#             ]
#           },
#           {
#             "text": "Natural language processing",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 1080,
#             "length": 27,
#             "confidenceScore": 0.98,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.98
#               }
#             ]
#           },
#           {
#             "text": "clinical trial documentation",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 1122,
#             "length": 28,
#             "confidenceScore": 0.75,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.75
#               }
#             ]
#           },
#           {
#             "text": "Predictive analytics",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 1158,
#             "length": 20,
#             "confidenceScore": 0.58,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.58
#               }
#             ]
#           },
#           {
#             "text": "platforms",
#             "category": "Location",
#             "type": "Location",
#             "offset": 1179,
#             "length": 9,
#             "confidenceScore": 0.67,
#             "tags": [
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.67
#               }
#             ]
#           },
#           {
#             "text": "supply chain management",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 1193,
#             "length": 23,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "AI",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 1224,
#             "length": 2,
#             "confidenceScore": 0.55,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.55
#               }
#             ]
#           },
#           {
#             "text": "manufacturing facilities",
#             "category": "Location",
#             "type": "Location",
#             "offset": 1263,
#             "length": 24,
#             "confidenceScore": 0.69,
#             "tags": [
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.69
#               }
#             ]
#           },
#           {
#             "text": "1.2",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1289,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 1.2
#             }
#           },
#           {
#             "text": "Services",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 1293,
#             "length": 8,
#             "confidenceScore": 0.88,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.88
#               }
#             ]
#           },
#           {
#             "text": "Client",
#             "category": "Location",
#             "type": "Location",
#             "offset": 1324,
#             "length": 6,
#             "confidenceScore": 0.5,
#             "tags": [
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.5
#               }
#             ]
#           },
#           {
#             "text": "s",
#             "category": "Location",
#             "type": "Location",
#             "offset": 1331,
#             "length": 1,
#             "confidenceScore": 0.5,
#             "tags": [
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.5
#               }
#             ]
#           },
#           {
#             "text": "facilities",
#             "category": "Location",
#             "subcategory": "Structural",
#             "type": "Structural",
#             "offset": 1333,
#             "length": 10,
#             "confidenceScore": 0.49,
#             "tags": [
#               {
#                 "name": "Structural",
#                 "confidenceScore": 0.49
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.49
#               }
#             ]
#           },
#           {
#             "text": "Raccoon City",
#             "category": "Location",
#             "subcategory": "City",
#             "type": "City",
#             "offset": 1355,
#             "length": 12,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "City",
#                 "confidenceScore": 1.0
#               },
#               {
#                 "name": "GPE",
#                 "confidenceScore": 1.0
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "New York",
#             "category": "Location",
#             "subcategory": "GPE",
#             "type": "GPE",
#             "offset": 1369,
#             "length": 8,
#             "confidenceScore": 0.78,
#             "tags": [
#               {
#                 "name": "GPE",
#                 "confidenceScore": 0.78
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.78
#               }
#             ]
#           },
#           {
#             "text": "headquarters",
#             "category": "Location",
#             "subcategory": "Structural",
#             "type": "Structural",
#             "offset": 1408,
#             "length": 12,
#             "confidenceScore": 0.9,
#             "tags": [
#               {
#                 "name": "Structural",
#                 "confidenceScore": 0.9
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.9
#               }
#             ]
#           },
#           {
#             "text": "Cleveland",
#             "category": "Location",
#             "subcategory": "City",
#             "type": "City",
#             "offset": 1424,
#             "length": 9,
#             "confidenceScore": 0.96,
#             "tags": [
#               {
#                 "name": "City",
#                 "confidenceScore": 0.96
#               },
#               {
#                 "name": "GPE",
#                 "confidenceScore": 0.99
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "Ohio",
#             "category": "Location",
#             "subcategory": "State",
#             "type": "State",
#             "offset": 1435,
#             "length": 4,
#             "confidenceScore": 0.93,
#             "tags": [
#               {
#                 "name": "State",
#                 "confidenceScore": 0.93
#               },
#               {
#                 "name": "GPE",
#                 "confidenceScore": 0.93
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.93
#               }
#             ]
#           },
#           {
#             "text": "2",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1442,
#             "length": 1,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 2.0
#             }
#           },
#           {
#             "text": "2.1",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1467,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 2.1
#             }
#           },
#           {
#             "text": "February 1, 2026",
#             "category": "DateTime",
#             "subcategory": "Date",
#             "type": "Date",
#             "offset": 1504,
#             "length": 16,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Date",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "DateTime",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "DateMetadata",
#               "dateValues": [
#                 {
#                   "timex": "2026-02-01",
#                   "value": "2026-02-01"
#                 }
#               ]
#             }
#           },
#           {
#             "text": "January 31, 2029",
#             "category": "DateTime",
#             "subcategory": "Date",
#             "type": "Date",
#             "offset": 1543,
#             "length": 16,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Date",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "DateTime",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "DateMetadata",
#               "dateValues": [
#                 {
#                   "timex": "2029-01-31",
#                   "value": "2029-01-31"
#                 }
#               ]
#             }
#           },
#           {
#             "text": "2.2",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1583,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 2.2
#             }
#           },
#           {
#             "text": "may",
#             "category": "DateTime",
#             "subcategory": "DateRange",
#             "type": "DateRange",
#             "offset": 1600,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "DateRange",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "DateTime",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "TemporalSpanMetadata",
#               "spanValues": [
#                 {
#                   "timex": "XXXX-05",
#                   "begin": "2025-05-01",
#                   "end": "2025-06-01"
#                 },
#                 {
#                   "timex": "XXXX-05",
#                   "begin": "2026-05-01",
#                   "end": "2026-06-01"
#                 }
#               ]
#             }
#           },
#           {
#             "text": "ninety",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1634,
#             "length": 6,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 90.0
#             }
#           },
#           {
#             "text": "90) days",
#             "category": "DateTime",
#             "subcategory": "Duration",
#             "type": "Duration",
#             "offset": 1642,
#             "length": 8,
#             "confidenceScore": 0.93,
#             "tags": [
#               {
#                 "name": "Duration",
#                 "confidenceScore": 0.93
#               },
#               {
#                 "name": "DateTime",
#                 "confidenceScore": 0.93
#               }
#             ]
#           },
#           {
#             "text": "3",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1687,
#             "length": 1,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 3.0
#             }
#           },
#           {
#             "text": "3.1",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1704,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 3.1
#             }
#           },
#           {
#             "text": "Client",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 1708,
#             "length": 6,
#             "confidenceScore": 0.96,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.96
#               }
#             ]
#           },
#           {
#             "text": "Provider",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 1729,
#             "length": 8,
#             "confidenceScore": 0.83,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.83
#               }
#             ]
#           },
#           {
#             "text": "$2,500,000 USD",
#             "category": "Quantity",
#             "subcategory": "Currency",
#             "type": "Currency",
#             "offset": 1796,
#             "length": 14,
#             "confidenceScore": 0.95,
#             "tags": [
#               {
#                 "name": "Currency",
#                 "confidenceScore": 0.95
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.95
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.95
#               }
#             ]
#           },
#           {
#             "text": "Monthly",
#             "category": "DateTime",
#             "subcategory": "Set",
#             "type": "Set",
#             "offset": 1818,
#             "length": 7,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Set",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "DateTime",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "TemporalSetMetadata",
#               "dateValues": [
#                 {
#                   "timex": "P1M",
#                   "value": "not resolved"
#                 }
#               ]
#             }
#           },
#           {
#             "text": "$175,000 USD",
#             "category": "Quantity",
#             "subcategory": "Currency",
#             "type": "Currency",
#             "offset": 1857,
#             "length": 12,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "Currency",
#                 "confidenceScore": 1.0
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 1.0
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "$350 USD",
#             "category": "Quantity",
#             "subcategory": "Currency",
#             "type": "Currency",
#             "offset": 1906,
#             "length": 8,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "Currency",
#                 "confidenceScore": 1.0
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 1.0
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "3.2",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1925,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 3.2
#             }
#           },
#           {
#             "text": "thirty",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1963,
#             "length": 6,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 30.0
#             }
#           },
#           {
#             "text": "30",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1971,
#             "length": 2,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 30.0
#             }
#           },
#           {
#             "text": "4",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 1993,
#             "length": 1,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 4.0
#             }
#           },
#           {
#             "text": "KEY PERSONNEL",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 1996,
#             "length": 13,
#             "confidenceScore": 0.68,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.68
#               }
#             ]
#           },
#           {
#             "text": "4.1",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 2011,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 4.1
#             }
#           },
#           {
#             "text": "Provider",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2015,
#             "length": 8,
#             "confidenceScore": 0.87,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.87
#               }
#             ]
#           },
#           {
#             "text": "personnel",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2068,
#             "length": 9,
#             "confidenceScore": 0.54,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.54
#               }
#             ]
#           },
#           {
#             "text": "Dr.",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2104,
#             "length": 3,
#             "confidenceScore": 0.52,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.52
#               }
#             ]
#           },
#           {
#             "text": "Caroline Johnson",
#             "category": "Person",
#             "type": "Person",
#             "offset": 2108,
#             "length": 16,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "Person",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "Chief AI Officer",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2126,
#             "length": 16,
#             "confidenceScore": 0.91,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.91
#               }
#             ]
#           },
#           {
#             "text": "Marcus Chen",
#             "category": "Person",
#             "type": "Person",
#             "offset": 2148,
#             "length": 11,
#             "confidenceScore": 0.98,
#             "tags": [
#               {
#                 "name": "Person",
#                 "confidenceScore": 0.98
#               }
#             ]
#           },
#           {
#             "text": "Director",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2161,
#             "length": 8,
#             "confidenceScore": 0.97,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.97
#               }
#             ]
#           },
#           {
#             "text": "Elena Rodriguez",
#             "category": "Person",
#             "type": "Person",
#             "offset": 2210,
#             "length": 15,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "Person",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "Lead Data Scientist",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2227,
#             "length": 19,
#             "confidenceScore": 0.91,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.91
#               }
#             ]
#           },
#           {
#             "text": "4.2",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 2248,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 4.2
#             }
#           },
#           {
#             "text": "Client",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2252,
#             "length": 6,
#             "confidenceScore": 0.87,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.87
#               }
#             ]
#           },
#           {
#             "text": "contacts",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2307,
#             "length": 8,
#             "confidenceScore": 0.47,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.47
#               }
#             ]
#           },
#           {
#             "text": "William Birkin",
#             "category": "Person",
#             "type": "Person",
#             "offset": 2322,
#             "length": 14,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "Person",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "VP of Research and Development",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2338,
#             "length": 30,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.8
#               }
#             ]
#           },
#           {
#             "text": "Annette Thompson",
#             "category": "Person",
#             "type": "Person",
#             "offset": 2378,
#             "length": 16,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "Person",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "Director of Information Technology",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2396,
#             "length": 34,
#             "confidenceScore": 0.74,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.74
#               }
#             ]
#           },
#           {
#             "text": "Albert Wesker",
#             "category": "Person",
#             "type": "Person",
#             "offset": 2436,
#             "length": 13,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "Person",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "Chief Operations Officer",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2451,
#             "length": 24,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "5",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 2477,
#             "length": 1,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 5.0
#             }
#           },
#           {
#             "text": "5.1",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 2503,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 5.1
#             }
#           },
#           {
#             "text": "Client",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2560,
#             "length": 6,
#             "confidenceScore": 0.97,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.97
#               }
#             ]
#           },
#           {
#             "text": "Client",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2606,
#             "length": 6,
#             "confidenceScore": 0.98,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.98
#               }
#             ]
#           },
#           {
#             "text": "5.2",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 2633,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 5.2
#             }
#           },
#           {
#             "text": "Provider",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 2637,
#             "length": 8,
#             "confidenceScore": 0.93,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.93
#               }
#             ]
#           },
#           {
#             "text": "intellectual property",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 2684,
#             "length": 21,
#             "confidenceScore": 0.66,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.66
#               }
#             ]
#           },
#           {
#             "text": "methodologies",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 2718,
#             "length": 13,
#             "confidenceScore": 0.73,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.73
#               }
#             ]
#           },
#           {
#             "text": "6",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 2734,
#             "length": 1,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 6.0
#             }
#           },
#           {
#             "text": "6.1",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 2754,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 6.1
#             }
#           },
#           {
#             "text": "confidentiality",
#             "category": "Skill",
#             "type": "Skill",
#             "offset": 2796,
#             "length": 15,
#             "confidenceScore": 0.97,
#             "tags": [
#               {
#                 "name": "Skill",
#                 "confidenceScore": 0.97
#               }
#             ]
#           },
#           {
#             "text": "engagement",
#             "category": "Event",
#             "type": "Event",
#             "offset": 2879,
#             "length": 10,
#             "confidenceScore": 0.56,
#             "tags": [
#               {
#                 "name": "Event",
#                 "confidenceScore": 0.56
#               }
#             ]
#           },
#           {
#             "text": "7",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 2892,
#             "length": 1,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Integer",
#               "value": 7.0
#             }
#           },
#           {
#             "text": "7.1",
#             "category": "Quantity",
#             "subcategory": "Number",
#             "type": "Number",
#             "offset": 2910,
#             "length": 3,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Number",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Quantity",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "NumberMetadata",
#               "numberKind": "Decimal",
#               "value": 7.1
#             }
#           },
#           {
#             "text": "Delaware",
#             "category": "Location",
#             "subcategory": "State",
#             "type": "State",
#             "offset": 2975,
#             "length": 8,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "State",
#                 "confidenceScore": 0.99
#               },
#               {
#                 "name": "GPE",
#                 "confidenceScore": 0.99
#               },
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "first",
#             "category": "Quantity",
#             "subcategory": "Ordinal",
#             "type": "Ordinal",
#             "offset": 3062,
#             "length": 5,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "Ordinal",
#                 "confidenceScore": 0.99
#               },
#               {
#                 "name": "Numeric",
#                 "confidenceScore": 0.99
#               }
#             ],
#             "metadata": {
#               "metadataKind": "OrdinalMetadata",
#               "offset": "1",
#               "relativeTo": "Start",
#               "value": "1"
#             }
#           },
#           {
#             "text": "APERTURE LABORATORIES, INC.",
#             "category": "Organization",
#             "type": "Organization",
#             "offset": 3084,
#             "length": 27,
#             "confidenceScore": 0.93,
#             "tags": [
#               {
#                 "name": "Organization",
#                 "confidenceScore": 0.93
#               }
#             ]
#           },
#           {
#             "text": "Dr.",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 3156,
#             "length": 3,
#             "confidenceScore": 0.56,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.56
#               }
#             ]
#           },
#           {
#             "text": "Cave Johnson",
#             "category": "Person",
#             "type": "Person",
#             "offset": 3160,
#             "length": 12,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "Person",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "Chief Executive Officer",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 3180,
#             "length": 23,
#             "confidenceScore": 1.0,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 1.0
#               }
#             ]
#           },
#           {
#             "text": "January 15, 2026",
#             "category": "DateTime",
#             "subcategory": "Date",
#             "type": "Date",
#             "offset": 3210,
#             "length": 16,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Date",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "DateTime",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "DateMetadata",
#               "dateValues": [
#                 {
#                   "timex": "2026-01-15",
#                   "value": "2026-01-15"
#                 }
#               ]
#             }
#           },
#           {
#             "text": "UMBRELLA CORPORATION",
#             "category": "Location",
#             "type": "Location",
#             "offset": 3228,
#             "length": 20,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Location",
#                 "confidenceScore": 0.8
#               }
#             ]
#           },
#           {
#             "text": "Oswell E. Spencer",
#             "category": "Person",
#             "type": "Person",
#             "offset": 3293,
#             "length": 17,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "Person",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "Chairman",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 3318,
#             "length": 8,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "CEO",
#             "category": "PersonType",
#             "type": "PersonType",
#             "offset": 3331,
#             "length": 3,
#             "confidenceScore": 0.99,
#             "tags": [
#               {
#                 "name": "PersonType",
#                 "confidenceScore": 0.99
#               }
#             ]
#           },
#           {
#             "text": "January 15, 2026",
#             "category": "DateTime",
#             "subcategory": "Date",
#             "type": "Date",
#             "offset": 3341,
#             "length": 16,
#             "confidenceScore": 0.8,
#             "tags": [
#               {
#                 "name": "Date",
#                 "confidenceScore": 0.8
#               },
#               {
#                 "name": "DateTime",
#                 "confidenceScore": 0.8
#               }
#             ],
#             "metadata": {
#               "metadataKind": "DateMetadata",
#               "dateValues": [
#                 {
#                   "timex": "2026-01-15",
#                   "value": "2026-01-15"
#                 }
#               ]
#             }
#           }
#         ],
#         "warnings": []
#       }
#     ],
#     "errors": [],
#     "modelVersion": "2025-11-01"
#   }
# }

# %% [markdown]
# ## Human-Friendly Results
#
# Present the named entities in a readable format, organized by category.

# %%
console = Console()

# Extract entities from the first document
entities = result["results"]["documents"][0]["entities"]

# Create main entity table
table = Table(title="Named Entities Recognized in Contract")
table.add_column("Entity", style="cyan")
table.add_column("Category", style="green")
table.add_column("Subcategory", style="dim")
table.add_column("Confidence", justify="center")

for entity in entities:
    confidence = f"{entity['confidenceScore']:.0%}"
    subcategory = entity.get("subcategory", "-")
    table.add_row(entity["text"], entity["category"], subcategory, confidence)

console.print(table)

# Group entities by category for summary
categories: dict[str, list[str]] = {}
for entity in entities:
    cat = entity["category"]
    if cat not in categories:
        categories[cat] = []
    if entity["text"] not in categories[cat]:
        categories[cat].append(entity["text"])

# Print category summary
console.print("\n")
summary_table = Table(title="Entity Summary by Category")
summary_table.add_column("Category", style="bold green")
summary_table.add_column("Count", justify="center", style="cyan")
summary_table.add_column("Unique Entities", style="dim")

for cat, ents in sorted(categories.items()):
    entities_preview = ", ".join(ents[:5])
    if len(ents) > 5:
        entities_preview += f" (+{len(ents) - 5} more)"
    summary_table.add_row(cat, str(len(ents)), entities_preview)

console.print(summary_table)

# Key contract parties
orgs = categories.get("Organization", [])
people = categories.get("Person", [])
locations = categories.get("Location", []) + categories.get("GPE", [])

key_info = f"""
[bold]Key Contract Information Extracted:[/bold]

[cyan]Organizations:[/cyan] {", ".join(orgs[:5]) if orgs else "None found"}
[cyan]People:[/cyan] {", ".join(people[:5]) if people else "None found"}
[cyan]Locations:[/cyan] {", ".join(locations[:5]) if locations else "None found"}
"""

console.print(Panel(key_info, title="Contract Parties & Locations"))
# Out:
#                                    Named Entities Recognized in Contract
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Entity                                                        ┃ Category     ┃ Subcategory ┃ Confidence ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━╇━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ January 15, 2026                                              │ DateTime     │ Date        │    80%     │
# │ APERTURE LABORATORIES, INC.                                   │ Organization │ -           │    86%     │
# │ Delaware                                                      │ Location     │ State       │    99%     │
# │ 1500 Innovation Drive, Cleveland, Ohio 44113                  │ Address      │ -           │    100%    │
# │ UMBRELLA CORPORATION                                          │ Organization │ -           │    99%     │
# │ State of New York                                             │ Location     │ GPE         │    76%     │
# │ headquarters                                                  │ Location     │ Structural  │    54%     │
# │ 2800 Corporate Plaza, Suite 500, Raccoon City, New York 10001 │ Address      │ -           │    100%    │
# │ machine learning                                              │ Skill        │ -           │    99%     │
# │ artificial intelligence research                              │ Skill        │ -           │    76%     │
# │ data analytics services                                       │ Skill        │ -           │    84%     │
# │ Client                                                        │ PersonType   │ -           │    92%     │
# │ machine learning                                              │ Skill        │ -           │    97%     │
# │ model development                                             │ Skill        │ -           │    100%    │
# │ AI infrastructure                                             │ Skill        │ -           │    83%     │
# │ NOW                                                           │ DateTime     │ -           │    70%     │
# │ 1                                                             │ Quantity     │ Number      │    80%     │
# │ 1.1                                                           │ Quantity     │ Number      │    80%     │
# │ Provider                                                      │ PersonType   │ -           │    91%     │
# │ Client                                                        │ PersonType   │ -           │    97%     │
# │ Development                                                   │ Skill        │ -           │    100%    │
# │ pharmaceutical research                                       │ Skill        │ -           │    84%     │
# │ optimization                                                  │ Skill        │ -           │    70%     │
# │ Natural language processing                                   │ Skill        │ -           │    98%     │
# │ clinical trial documentation                                  │ Skill        │ -           │    75%     │
# │ Predictive analytics                                          │ Skill        │ -           │    58%     │
# │ platforms                                                     │ Location     │ -           │    67%     │
# │ supply chain management                                       │ Skill        │ -           │    100%    │
# │ AI                                                            │ Skill        │ -           │    55%     │
# │ manufacturing facilities                                      │ Location     │ -           │    69%     │
# │ 1.2                                                           │ Quantity     │ Number      │    80%     │
# │ Services                                                      │ Skill        │ -           │    88%     │
# │ Client                                                        │ Location     │ -           │    50%     │
# │ s                                                             │ Location     │ -           │    50%     │
# │ facilities                                                    │ Location     │ Structural  │    49%     │
# │ Raccoon City                                                  │ Location     │ City        │    100%    │
# │ New York                                                      │ Location     │ GPE         │    78%     │
# │ headquarters                                                  │ Location     │ Structural  │    90%     │
# │ Cleveland                                                     │ Location     │ City        │    96%     │
# │ Ohio                                                          │ Location     │ State       │    93%     │
# │ 2                                                             │ Quantity     │ Number      │    80%     │
# │ 2.1                                                           │ Quantity     │ Number      │    80%     │
# │ February 1, 2026                                              │ DateTime     │ Date        │    80%     │
# │ January 31, 2029                                              │ DateTime     │ Date        │    80%     │
# │ 2.2                                                           │ Quantity     │ Number      │    80%     │
# │ may                                                           │ DateTime     │ DateRange   │    80%     │
# │ ninety                                                        │ Quantity     │ Number      │    80%     │
# │ 90) days                                                      │ DateTime     │ Duration    │    93%     │
# │ 3                                                             │ Quantity     │ Number      │    80%     │
# │ 3.1                                                           │ Quantity     │ Number      │    80%     │
# │ Client                                                        │ PersonType   │ -           │    96%     │
# │ Provider                                                      │ PersonType   │ -           │    83%     │
# │ $2,500,000 USD                                                │ Quantity     │ Currency    │    95%     │
# │ Monthly                                                       │ DateTime     │ Set         │    80%     │
# │ $175,000 USD                                                  │ Quantity     │ Currency    │    100%    │
# │ $350 USD                                                      │ Quantity     │ Currency    │    100%    │
# │ 3.2                                                           │ Quantity     │ Number      │    80%     │
# │ thirty                                                        │ Quantity     │ Number      │    80%     │
# │ 30                                                            │ Quantity     │ Number      │    80%     │
# │ 4                                                             │ Quantity     │ Number      │    80%     │
# │ KEY PERSONNEL                                                 │ PersonType   │ -           │    68%     │
# │ 4.1                                                           │ Quantity     │ Number      │    80%     │
# │ Provider                                                      │ PersonType   │ -           │    87%     │
# │ personnel                                                     │ PersonType   │ -           │    54%     │
# │ Dr.                                                           │ PersonType   │ -           │    52%     │
# │ Caroline Johnson                                              │ Person       │ -           │    100%    │
# │ Chief AI Officer                                              │ PersonType   │ -           │    91%     │
# │ Marcus Chen                                                   │ Person       │ -           │    98%     │
# │ Director                                                      │ PersonType   │ -           │    97%     │
# │ Elena Rodriguez                                               │ Person       │ -           │    99%     │
# │ Lead Data Scientist                                           │ PersonType   │ -           │    91%     │
# │ 4.2                                                           │ Quantity     │ Number      │    80%     │
# │ Client                                                        │ PersonType   │ -           │    87%     │
# │ contacts                                                      │ PersonType   │ -           │    47%     │
# │ William Birkin                                                │ Person       │ -           │    99%     │
# │ VP of Research and Development                                │ PersonType   │ -           │    80%     │
# │ Annette Thompson                                              │ Person       │ -           │    100%    │
# │ Director of Information Technology                            │ PersonType   │ -           │    74%     │
# │ Albert Wesker                                                 │ Person       │ -           │    99%     │
# │ Chief Operations Officer                                      │ PersonType   │ -           │    99%     │
# │ 5                                                             │ Quantity     │ Number      │    80%     │
# │ 5.1                                                           │ Quantity     │ Number      │    80%     │
# │ Client                                                        │ PersonType   │ -           │    97%     │
# │ Client                                                        │ PersonType   │ -           │    98%     │
# │ 5.2                                                           │ Quantity     │ Number      │    80%     │
# │ Provider                                                      │ PersonType   │ -           │    93%     │
# │ intellectual property                                         │ Skill        │ -           │    66%     │
# │ methodologies                                                 │ Skill        │ -           │    73%     │
# │ 6                                                             │ Quantity     │ Number      │    80%     │
# │ 6.1                                                           │ Quantity     │ Number      │    80%     │
# │ confidentiality                                               │ Skill        │ -           │    97%     │
# │ engagement                                                    │ Event        │ -           │    56%     │
# │ 7                                                             │ Quantity     │ Number      │    80%     │
# │ 7.1                                                           │ Quantity     │ Number      │    80%     │
# │ Delaware                                                      │ Location     │ State       │    99%     │
# │ first                                                         │ Quantity     │ Ordinal     │    99%     │
# │ APERTURE LABORATORIES, INC.                                   │ Organization │ -           │    93%     │
# │ Dr.                                                           │ PersonType   │ -           │    56%     │
# │ Cave Johnson                                                  │ Person       │ -           │    99%     │
# │ Chief Executive Officer                                       │ PersonType   │ -           │    100%    │
# │ January 15, 2026                                              │ DateTime     │ Date        │    80%     │
# │ UMBRELLA CORPORATION                                          │ Location     │ -           │    80%     │
# │ Oswell E. Spencer                                             │ Person       │ -           │    99%     │
# │ Chairman                                                      │ PersonType   │ -           │    99%     │
# │ CEO                                                           │ PersonType   │ -           │    99%     │
# │ January 15, 2026                                              │ DateTime     │ Date        │    80%     │
# └───────────────────────────────────────────────────────────────┴──────────────┴─────────────┴────────────┘
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
#                                             Entity Summary by Category
# ┏━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Category     ┃ Count ┃ Unique Entities                                                                          ┃
# ┡━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ Address      │   2   │ 1500 Innovation Drive, Cleveland, Ohio 44113, 2800 Corporate Plaza, Suite 500, Raccoon   │
# │              │       │ City, New York 10001                                                                     │
# │ DateTime     │   7   │ January 15, 2026, NOW, February 1, 2026, January 31, 2029, may (+2 more)                 │
# │ Event        │   1   │ engagement                                                                               │
# │ Location     │  13   │ Delaware, State of New York, headquarters, platforms, manufacturing facilities (+8 more) │
# │ Organization │   2   │ APERTURE LABORATORIES, INC., UMBRELLA CORPORATION                                        │
# │ Person       │   8   │ Caroline Johnson, Marcus Chen, Elena Rodriguez, William Birkin, Annette Thompson (+3     │
# │              │       │ more)                                                                                    │
# │ PersonType   │  15   │ Client, Provider, KEY PERSONNEL, personnel, Dr. (+10 more)                               │
# │ Quantity     │  26   │ 1, 1.1, 1.2, 2, 2.1 (+21 more)                                                           │
# │ Skill        │  17   │ machine learning, artificial intelligence research, data analytics services, model       │
# │              │       │ development, AI infrastructure (+12 more)                                                │
# └──────────────┴───────┴──────────────────────────────────────────────────────────────────────────────────────────┘
# ╭───────────────────────────────────────── Contract Parties & Locations ──────────────────────────────────────────╮
# │                                                                                                                 │
# │ Key Contract Information Extracted:                                                                             │
# │                                                                                                                 │
# │ Organizations: APERTURE LABORATORIES, INC., UMBRELLA CORPORATION                                                │
# │ People: Caroline Johnson, Marcus Chen, Elena Rodriguez, William Birkin, Annette Thompson                        │
# │ Locations: Delaware, State of New York, headquarters, platforms, manufacturing facilities                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
